# %%
def view_books():
    print("Books are listed",library)
def add_books(book_name,author_name):
    if book_name not in library.keys():
        #library[title]=title
        library[book_name] = {"author": author_name, "available": True}
    else:
        print("Book already Exist")
    return library
def issue_book(book_name, person_name):
    if book_name in library.keys() :
        library[book_name] = { "available": False}
        issued_book[book_name]={"name":person_name}
def return_book(book_name):
    library[book_name]={"available":True}
    del(issued_book[book_name])
def view_issue_books():
    print(issued_book)


usr=input("Enter User Name")
psswd=input("Enter admin Password")
library={}
issued_book={}
credentials = {"admin": "admin123", "librarian": "lib123"}
if usr=="admin" and psswd==credentials["admin"]:
    print("Welcome to Library")
    while True:
        inputt=int(input("Enter your choice\n1.View Books\n2. Add Books\n3.Issue Books\n4.Return Book\n5. View Issued Books\n6. Exit"))

        
        if inputt==1:
            view_books()
        elif inputt==2:
            book_name=input("Enter Book Name")
            author_name=input("Author Name")
            add_books(book_name,author_name)
        elif inputt==3:
            book_name=input("Enter Book Name")
            person_name=input("Person Name")
            issue_book(book_name,person_name)
        elif inputt==4:
            return_book(book_name)
        elif inputt==5:
            view_issue_books()
        elif inputt==6:
            break
        else:
           print("Invalid Code")
elif usr=="librarian" and psswd=="lib123":
    while True:
        inputt=int(input("Enter your choice\n1.View Books\n2.Issue Books\n3.Return Book\n4. View Issued Books\n5. Exit"))

        
        if inputt==1:
            view_books()
        elif inputt==2:
            book_name=input("Enter Book Name")
            person_name=input("Person Name")
            issue_book(book_name,person_name)
        elif inputt==3:
            return_book(book_name)
        elif inputt==4:
            view_issue_books()
        elif inputt==5:
            break
        else:
           print("Invalid Code")
else:
    print("Invalid Credentials")
# Out:
# Enter User Name librarian
# Enter admin Password lib123
# Enter your choice
# 1.View Books
# 2.Issue Books
# 3.Return Book
# 4. View Issued Books
# 5. Exit 1
# Books are listed {}
